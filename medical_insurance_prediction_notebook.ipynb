# %% [markdown]
# # TASK #1: UNDERSTANDING THE PROBLEM STATEMENT

# %% [markdown]
# - Aim of the problem is to find the health insurance cost incured by Individuals based on thier age, gender, BMI, number of children, smoking habit and geo-location.
#
# - Features available are:
#
#     - sex: insurance contractor gender, female, male
#
#     - bmi: Body mass index (ideally 18.5 to 24.9)
#
#     - children: Number of children covered by health insurance / Number of dependents
#
#     - smoker: smoking habits
#
#     - region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
#     - charges: Individual medical costs billed by health insurance
#
#
# Data Source:https://www.kaggle.com/mirichoi0218/insurance

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file 
insurance_df = pd.read_csv("/Users/viveknarayan/Documents/Northeastern/Fall 2020/EAI6000/Week_4/insurance.csv")

# %%
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS:

# %%
insurance_df.shape
# Out:
# (1338, 7)

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check if there are any Duplicates values
insurance_df[insurance_df.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
insurance_df=insurance_df.drop_duplicates()

# %%
insurance_df.shape
# Out:
# (1337, 7)

# %%
# Check the dataframe info

insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
df_region = insurance_df.groupby(by='region').mean()
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.259259  29.195494  1.151235  12450.840844
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %%
# Grouping by age to see any relationship between age and charges
# Seems like charges increases by age
df_age = insurance_df.groupby(by='age').mean()
df_age
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.567164  0.432836   9868.929428
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# ...

# %%
# Check unique values in the 'sex' column
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical

insurance_df['sex'] = insurance_df['sex'].apply(lambda x: 0 if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical 

insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1337 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          1
# 4   32    1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
# Let's drop the original 'region' column 
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # TASK #4: VISUALIZE DATASET

# %%
insurance_df[['age', 'sex', 'bmi', 'children', 'smoker', 'charges']].hist(bins = 30, figsize = (20,20), color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>],
#        [<AxesSubplot:title={'center':'bmi'}>,
#         <AxesSubplot:title={'center':'children'}>],
#        [<AxesSubplot:title={'center':'smoker'}>,
#         <AxesSubplot:title={'center':'charges'}>]], dtype=object)

# %%
# plot pairplot

sns.pairplot(insurance_df)

# %%
# regplot between age and charges
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
# regplot between bmi and charges
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %%
cor = insurance_df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %%
# smoker and age have positive correlations with charges

# %% [markdown]
# # TASK #5: CREATE TRAINING AND TESTING DATASET

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns =['charges'])
y = insurance_df['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1337 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
X.shape
# Out:
# (1337, 8)

# %%
y.shape
# Out:
# (1337,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Only take the numerical variables and scale them
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
y.shape
# Out:
# (1337, 1)

# %% [markdown]
# # TASK #6: TRAIN AND TEST A SUPPORT VECTOR REGRESSION MODEL IN SK-LEARN

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
# using Support Vector regression model
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, accuracy_score

regresssion_model_sklearn = SVR(kernel='rbf')
regresssion_model_sklearn.fit(X_train, y_train)
# Out:
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %%
regresssion_model_sklearn_accuracy = regresssion_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.8404799308105866

# %%
y_predict = regresssion_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
print(k)
n
# Out:
# 8
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)

# %%
MAE= mean_absolute_error(y_test_orig, y_predict_orig)
r2=r2_score(y_test_orig, y_predict_orig)
adj_r2= 1-(1-r2)*(n-1)/(n-k-1)

# %%
print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.428
# MSE = 0.18311693607801102
# MAE = 0.23941479806228694
# R2 = 0.8404799313362502
# Adjusted R2 = 0.8355526705281034

# %%
# SVM Hyperparameter Tuning using GridSearchCV

from sklearn.model_selection import GridSearchCV 

# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
'kernel': ['rbf']} 

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3) 

# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.246, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.264, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.174, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.188, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.132, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.766, total=   0.0s
# ...

# %%
# print best parameter after tuning 
print(grid.best_params_) 

# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# SVR(C=100, gamma=0.01)

# %%
grid_predictions = grid.predict(X_test) 

regresssion_model_sklearn_accuracy = grid.score(X_test, y_test)
print(regresssion_model_sklearn_accuracy)
# Out:
# 0.8452780258791046

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, grid_predictions)),'.3f'))
MSE = mean_squared_error(y_test_orig, grid_predictions)
print(RMSE)
print(MSE)
# Out:
# 0.421
# 0.17760908756068647
